# %%
import sys,os
sys.path.append(os.path.abspath(".."))

# %%
from QuantumWalkModule.EM_OneDimensionQW import *
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

# %%
import seaborn as sns
sns.set(style="darkgrid")

# %%
plt.rc('font', family='serif')
plt.rcParams.update({'font.size': 22})

# %%
steps = 100
dim = 100
coin_conf = {
    "th" : np.pi/3
}

ratios = [0.1,np.sqrt(2)/5,1/3,np.sqrt(5)]
ratio_titles = [r"$0.1$" , r"$\sqrt{2}/5$" ,r"$0.5$",r"$\sqrt{5}$"]

fig = plt.figure(figsize = (10,8))

for i, ratio in enumerate(ratios):
    field_conf = {
        "name" : "uniform",
        "ratio" : ratio
    }
    model = Electric_QW_1d(dim , coin_conf,field_conf)
    data = model.run(steps,state = "Gaussian",mu = dim // 2,sigma = dim /50,a = 1j,b = -1j)
    ax = fig.add_subplot(2,2,i + 1)
    im = ax.imshow(data, origin = "lower",cmap = "viridis",alpha = 0.95)
    plt.colorbar(im, fraction=0.05, pad=0.09)
    plt.grid(False)
    ax.set_xlabel("x", fontsize = 22)
    ax.set_ylabel("t", fontsize = 22)
    ax.set_title(r"$\phi / 2\pi = $" + ratio_titles[i], fontsize = 22)
plt.tight_layout()
plt.show()

fig.savefig("Images/ElectricWalks1.pdf",format= "pdf",bbox_inches = "tight")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 21
#      19 ax = fig.add_subplot(2,2,i + 1)
#      20 im = ax.imshow(data, origin = "lower",cmap = "viridis",alpha = 0.95)
# ---> 21 plt.colorbar(im, fraction=0.05, pad=0.09, fontsize = 22)
#      22 plt.grid(False)
#      23 ax.set_xlabel("x", fontsize = 22)
#
# File /opt/anaconda3/envs/d2l/lib/python3.9/site-packages/matplotlib/pyplot.py:2137, in colorbar(mappable, cax, ax, **kwargs)
#    2132     if mappable is None:
#    2133         raise RuntimeError('No mappable was found to use for colorbar '
#    2134                            'creation. First define a mappable such as '
#    2135                            'an image (with imshow) or a contour set ('
#    2136                            'with contourf).')
# -> 2137 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2138 return ret
#
# ...
